# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("fake_job_postings.csv")

# %%
data
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15184 non-null  object
#  8   benefits             10668 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
data.describe()
# Out:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count  17880.000000   17880.000000      17880.000000   17880.000000
# mean    8940.500000       0.042897          0.795302       0.491723
# std     5161.655742       0.202631          0.403492       0.499945
# min        1.000000       0.000000          0.000000       0.000000
# 25%     4470.750000       0.000000          1.000000       0.000000
# 50%     8940.500000       0.000000          1.000000       0.000000
# 75%    13410.250000       0.000000          1.000000       1.000000
# max    17880.000000       1.000000          1.000000       1.000000
#
#          fraudulent
# count  17880.000000
# mean       0.048434
# std        0.214688
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
data.isna().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2696
# benefits                7212
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
data = data.dropna()

# %%
data
# Out:
#        job_id                                              title  \
# 6           7                              Head of Content (m/f)
# 15         16                         VP of Sales - Vault Dragon
# 23         24  Vice President, Sales and Sponsorship (Busines...
# 98         99                                    IC&E Technician
# 102       103                            Marketing Administrator
# ...       ...                                                ...
# 17734   17735                    Customer Service Representative
# 17759   17760                    Customer Service Representative
# 17813   17814                    Customer Service Representative
# 17849   17850                             Communication Designer
# 17865   17866  Portfolio Development Associate - Paris & rest...
#
#                     location          department   salary_range  \
# 6             DE, BE, Berlin          ANDROIDPIT    20000-28000
# ...

# %%
data.isna().sum()
# Out:
# job_id                 0
# title                  0
# location               0
# department             0
# salary_range           0
# company_profile        0
# description            0
# requirements           0
# benefits               0
# telecommuting          0
# has_company_logo       0
# has_questions          0
# employment_type        0
# required_experience    0
# required_education     0
# industry               0
# function               0
# fraudulent             0
# dtype: int64

# %%
data.dtypes
# Out:
# job_id                  int64
# title                  object
# location               object
# department             object
# salary_range           object
# company_profile        object
# description            object
# requirements           object
# benefits               object
# telecommuting           int64
# has_company_logo        int64
# has_questions           int64
# employment_type        object
# required_experience    object
# required_education     object
# industry               object
# function               object
# fraudulent              int64
# dtype: object

# %%
data = data.reset_index(drop=True)

# %%
data
# Out:
#      job_id                                              title  \
# 0         7                              Head of Content (m/f)
# 1        16                         VP of Sales - Vault Dragon
# 2        24  Vice President, Sales and Sponsorship (Busines...
# 3        99                                    IC&E Technician
# 4       103                            Marketing Administrator
# ..      ...                                                ...
# 769   17735                    Customer Service Representative
# 770   17760                    Customer Service Representative
# 771   17814                    Customer Service Representative
# 772   17850                             Communication Designer
# 773   17866  Portfolio Development Associate - Paris & rest...
#
#                   location          department   salary_range  \
# 0           DE, BE, Berlin          ANDROIDPIT    20000-28000
# 1        SG, 01, Singapore               Sales  120000-150000
# ...

# %%
data.plot()
# Out:
# <Axes: >

# %%
x = data[data['employment_type'] == 'Full-time']

# %%
x
# Out:
#      job_id                                              title  \
# 0         7                              Head of Content (m/f)
# 1        16                         VP of Sales - Vault Dragon
# 2        24  Vice President, Sales and Sponsorship (Busines...
# 3        99                                    IC&E Technician
# 4       103                            Marketing Administrator
# ..      ...                                                ...
# 769   17735                    Customer Service Representative
# 770   17760                    Customer Service Representative
# 771   17814                    Customer Service Representative
# 772   17850                             Communication Designer
# 773   17866  Portfolio Development Associate - Paris & rest...
#
#                   location          department   salary_range  \
# 0           DE, BE, Berlin          ANDROIDPIT    20000-28000
# 1        SG, 01, Singapore               Sales  120000-150000
# ...

# %%
y = data[data['employment_type'] == 'Part-time']

# %%
y
# Out:
#      job_id                                              title  \
# 26      613                               Packing Expert - NYC
# 45     1005                            Assistant Sales Manager
# 61     1437  Physical Occupational Therapy Case Manager-Fie...
# 82     1742            Administrative Assistant To Lead Pastor
# 102    2334                                         Chat Agent
# 176    4022                 Cosmetics and Beauty Sales Advisor
# 189    4424                                Promotion Assistant
# 233    5562               Accounting Administrator (Part time)
# 264    6334                    Sales Professional- Mid Market
# 286    6758                                Sr. Office Manager
# 292    6800                    Sales Professional- Mid Market
# 390    8580            Senior Beauty Sales Advisor (part time)
# 403    8780                          Payroll/HR  Administrator
# 530   11673                  Sales Professional- SMB Division
# ...

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'job_id'}>,
#         <Axes: title={'center': 'telecommuting'}>],
#        [<Axes: title={'center': 'has_company_logo'}>,
#         <Axes: title={'center': 'has_questions'}>],
#        [<Axes: title={'center': 'fraudulent'}>, <Axes: >]], dtype=object)

# %%
data.plot(kind='bar')
# Out:
# <Axes: >

# %%
data.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer

# Load the dataset
data = pd.read_csv("fake_job_postings.csv")

# Drop any rows with missing values
data = data.dropna()

# Encode categorical features
categorical_features = ['employment_type', 'required_experience', 'required_education', 'industry', 'function']
encoder = LabelEncoder()
for feature in categorical_features:
    data[feature] = encoder.fit_transform(data[feature])

# Scale numerical features
numerical_features = ['telecommuting', 'has_company_logo', 'has_questions', 'fraudulent']
scaler = StandardScaler()
data[numerical_features] = scaler.fit_transform(data[numerical_features])

# Perform data analysis
summary = data.describe()
null_counts = data.isna().sum()
unique_counts = data.nunique()

# Print the results
print("Summary Statistics:")
print(summary)
print("\nNull Value Counts:")
print(null_counts)
print("\nUnique Value Counts:")
print(unique_counts)
# Out:
# Summary Statistics:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count    774.000000   7.740000e+02      7.740000e+02   7.740000e+02
# mean    8664.093023   4.131062e-17      1.377021e-17  -2.754042e-17
# std     5014.106692   1.000647e+00      1.000647e+00   1.000647e+00
# min        7.000000  -3.227026e-01     -6.673036e+00  -1.435022e+00
# 25%     4483.500000  -3.227026e-01      1.498568e-01  -1.435022e+00
# 50%     8542.000000  -3.227026e-01      1.498568e-01   6.968534e-01
# 75%    12922.250000  -3.227026e-01      1.498568e-01   6.968534e-01
# max    17866.000000   3.098829e+00      1.498568e-01   6.968534e-01
#
#        employment_type  required_experience  required_education    industry  \
# count       774.000000           774.000000          774.000000  774.000000
# mean          1.027132             2.852713            2.581395   32.574935
# std           0.455568             2.188766            2.258339   16.049130
# ...
